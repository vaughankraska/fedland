# %% [markdown]
# | Experiment ID       | Description       |
# |-----------------|----------------|
# | 9070ebff-43ab-4eeb-9a8a-d64024ee8e04| IID Balanced FedAvg ResNet|
# | 5f5b1857-84e7-4620-aa9c-77f9ea5e12da| Non-IID Imbalanced FedAdam ResNet|
# |be13a352-7c46-4fdc-9b1d-779275ab7785|IID Balanced FedAvg FedNet|
# |81802054-586c-4295-9aaf-7211b81d3250|Non-IID Imbalanced FedAvg FedNet|

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json

# %%
def get_json(file_path):
    with open(file_path) as f:
        data = json.load(f)
    return data

# %%
def get_experiment_data_5clients(file_path):
    import numpy as np
    import pandas as pd
    training_data0 = get_json(file_path+'/0/training.json')
    training_data1 = get_json(file_path+'/1/training.json')
    training_data2 = get_json(file_path+'/2/training.json')
    training_data3 = get_json(file_path+'/3/training.json')
    training_data4 = get_json(file_path+'/4/training.json')
    validate_data0 = get_json(file_path+'/0/validate.json')
    validate_data1 = get_json(file_path+'/1/validate.json')
    validate_data2 = get_json(file_path+'/2/validate.json')
    validate_data3 = get_json(file_path+'/3/validate.json')
    validate_data4 = get_json(file_path+'/4/validate.json')
    training_data0 = pd.DataFrame(training_data0)
    training_data1 = pd.DataFrame(training_data1)
    training_data2 = pd.DataFrame(training_data2)
    training_data3 = pd.DataFrame(training_data3)
    training_data4 = pd.DataFrame(training_data4)
    validate_data0 = pd.DataFrame(validate_data0)
    validate_data1 = pd.DataFrame(validate_data1)
    validate_data2 = pd.DataFrame(validate_data2)
    validate_data3 = pd.DataFrame(validate_data3)
    validate_data4 = pd.DataFrame(validate_data4)
    return training_data0, training_data1, training_data2, training_data3, training_data4, validate_data0, validate_data1, validate_data2, validate_data3, validate_data4

# %%
ex1_training_data0, ex1_training_data1, ex1_training_data2, ex1_training_data3, ex1_training_data4, ex1_validate_data0, ex1_validate_data1, ex1_validate_data2, ex1_validate_data3, ex1_validate_data4 = get_experiment_data_5clients('/Users/max/Fedn_Project/CIFAR10_Experiments/5clients/FedNet/be13a352-7c46-4fdc-9b1d-779275ab7785')
ex2_training_data0, ex2_training_data1, ex2_training_data2, ex2_training_data3, ex2_training_data4, ex2_validate_data0, ex2_validate_data1, ex2_validate_data2, ex2_validate_data3, ex2_validate_data4 = get_experiment_data_5clients('/Users/max/Fedn_Project/CIFAR10_Experiments/5clients/FedNet/81802054-586c-4295-9aaf-7211b81d3250')
ex3_training_data0, ex3_training_data1, ex3_training_data2, ex3_training_data3, ex3_training_data4, ex3_validate_data0, ex3_validate_data1, ex3_validate_data2, ex3_validate_data3, ex3_validate_data4 = get_experiment_data_5clients('/Users/max/Fedn_Project/CIFAR10_Experiments/5clients/ResNet/9070ebff-43ab-4eeb-9a8a-d64024ee8e04')
ex4_training_data0, ex4_training_data1, ex4_training_data2, ex4_training_data3, ex4_training_data4, ex4_validate_data0, ex4_validate_data1, ex4_validate_data2, ex4_validate_data3, ex4_validate_data4 = get_experiment_data_5clients('/Users/max/Fedn_Project/CIFAR10_Experiments/5clients/ResNet/5f5b1857-84e7-4620-aa9c-77f9ea5e12da')

# %%
ex1client0_path_norm = ex1_training_data0['path_norm']
ex1client1_path_norm = ex1_training_data1['path_norm']
ex1client2_path_norm = ex1_training_data2['path_norm']
ex1client3_path_norm = ex1_training_data3['path_norm']
ex1client4_path_norm = ex1_training_data4['path_norm']
ex1relative_change_client0_path_norm = ex1client0_path_norm.pct_change() * 100
ex1relative_change_client1_path_norm = ex1client1_path_norm.pct_change() * 100
ex1relative_change_client2_path_norm = ex1client2_path_norm.pct_change() * 100
ex1relative_change_client3_path_norm = ex1client3_path_norm.pct_change() * 100
ex1relative_change_client4_path_norm = ex1client4_path_norm.pct_change() * 100
ex1global_path_norm = ex1_validate_data0['path_norm']
ex1relative_change_global_path_norm = ex1global_path_norm.pct_change() * 100
ex1sampled_global_index = range(0, len(ex1relative_change_client1_path_norm), 5)


ex2client0_path_norm = ex2_training_data0['path_norm']
ex2client1_path_norm = ex2_training_data1['path_norm']
ex2client2_path_norm = ex2_training_data2['path_norm']
ex2client3_path_norm = ex2_training_data3['path_norm']
ex2client4_path_norm = ex2_training_data4['path_norm']
ex2relative_change_client0_path_norm = ex2client0_path_norm.pct_change() * 100
ex2relative_change_client1_path_norm = ex2client1_path_norm.pct_change() * 100
ex2relative_change_client2_path_norm = ex2client2_path_norm.pct_change() * 100
ex2relative_change_client3_path_norm = ex2client3_path_norm.pct_change() * 100
ex2relative_change_client4_path_norm = ex2client4_path_norm.pct_change() * 100
ex2global_path_norm = ex2_validate_data0['path_norm']
ex2relative_change_global_path_norm = ex2global_path_norm.pct_change() * 100
ex2sampled_global_index = range(0, len(ex2relative_change_client1_path_norm), 5)


ex3client0_path_norm = ex3_training_data0['path_norm']
ex3client1_path_norm = ex3_training_data1['path_norm']
ex3client2_path_norm = ex3_training_data2['path_norm']
ex3client3_path_norm = ex3_training_data3['path_norm']
ex3client4_path_norm = ex3_training_data4['path_norm']
ex3relative_change_client0_path_norm = ex3client0_path_norm.pct_change() * 100
ex3relative_change_client1_path_norm = ex3client1_path_norm.pct_change() * 100
ex3relative_change_client2_path_norm = ex3client2_path_norm.pct_change() * 100
ex3relative_change_client3_path_norm = ex3client3_path_norm.pct_change() * 100
ex3relative_change_client4_path_norm = ex3client4_path_norm.pct_change() * 100
ex3global_path_norm = ex3_validate_data0['path_norm'] 
ex3relative_change_global_path_norm = ex3global_path_norm.pct_change() * 100
ex3sampled_global_index = range(0, len(ex3relative_change_client1_path_norm), 3)


ex4client0_path_norm = ex4_training_data0['path_norm']
ex4client1_path_norm = ex4_training_data1['path_norm']
ex4client2_path_norm = ex4_training_data2['path_norm']
ex4client3_path_norm = ex4_training_data3['path_norm']
ex4client4_path_norm = ex4_training_data4['path_norm']
ex4relative_change_client0_path_norm = ex4client0_path_norm.pct_change() * 100
ex4relative_change_client1_path_norm = ex4client1_path_norm.pct_change() * 100
ex4relative_change_client2_path_norm = ex4client2_path_norm.pct_change() * 100
ex4relative_change_client3_path_norm = ex4client3_path_norm.pct_change() * 100
ex4relative_change_client4_path_norm = ex4client4_path_norm.pct_change() * 100
ex4global_path_norm = ex4_validate_data0['path_norm']
ex4relative_change_global_path_norm = ex4global_path_norm.pct_change() * 100
ex4sampled_global_index = range(0, len(ex4relative_change_client1_path_norm), 3)

# %%
import matplotlib.pyplot as plt

# Create a 2x2 layout for subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 10))

axes[0, 0].plot(ex1relative_change_client0_path_norm, label='Client 0', color='blue')
axes[0, 0].plot(ex1relative_change_client1_path_norm, label='Client 1', color='green')
axes[0, 0].plot(ex1relative_change_client2_path_norm, label='Client 2', color='orange')
axes[0, 0].plot(ex1relative_change_client3_path_norm, label='Client 3', color='purple')
axes[0, 0].plot(ex1relative_change_client4_path_norm, label='Client 4', color='brown')
axes[0, 0].plot(ex1sampled_global_index, ex1relative_change_global_path_norm, label='Global', color='red', marker='o')
axes[0, 0].set_title("Relative Change in Path Norm(5Clinets IID Balanced FedAvg FedNet)")
axes[0, 0].set_xlabel("Index")
axes[0, 0].set_ylabel("Percentage Change (%)")
axes[0, 0].axhline(0, color='red', linestyle='--', linewidth=1)
axes[0, 0].legend()

axes[0, 1].plot(ex2relative_change_client0_path_norm, label='Client 0', color='blue')
axes[0, 1].plot(ex2relative_change_client1_path_norm, label='Client 1', color='green')
axes[0, 1].plot(ex2relative_change_client2_path_norm, label='Client 2', color='orange')
axes[0, 1].plot(ex2relative_change_client3_path_norm, label='Client 3', color='purple')
axes[0, 1].plot(ex2relative_change_client4_path_norm, label='Client 4', color='brown')
axes[0, 1].plot(ex2sampled_global_index, ex2relative_change_global_path_norm, label='Global', color='red', marker='o')
axes[0, 1].set_title("Relative Change in Path Norm(5Clinets Non-IID Imbalanced FedAvg FedNet)")
axes[0, 1].set_xlabel("Index")
axes[0, 1].set_ylabel("Percentage Change (%)")
axes[0, 1].axhline(0, color='red', linestyle='--', linewidth=1)
axes[0, 1].legend()



axes[1, 0].plot(ex3relative_change_client0_path_norm, label='Client 0', color='blue')
axes[1, 0].plot(ex3relative_change_client1_path_norm, label='Client 1', color='green')
axes[1, 0].plot(ex3relative_change_client2_path_norm, label='Client 2', color='orange')
axes[1, 0].plot(ex3relative_change_client3_path_norm, label='Client 3', color='purple')
axes[1, 0].plot(ex3relative_change_client4_path_norm, label='Client 4', color='brown')
axes[1, 0].plot(ex3sampled_global_index, ex3relative_change_global_path_norm, label='Global', color='red', marker='o')
axes[1, 0].set_title("Relative Change in Path Norm(5Clinets IID Balanced FedAvg ResNet)")
axes[1, 0].set_xlabel("Index")
axes[1, 0].set_ylabel("Percentage Change (%)")
axes[1, 0].axhline(0, color='red', linestyle='--', linewidth=1)
axes[1, 0].legend()

axes[1, 1].plot(ex4relative_change_client0_path_norm, label='Client 0', color='blue')
axes[1, 1].plot(ex4relative_change_client1_path_norm, label='Client 1', color='green')
axes[1, 1].plot(ex4relative_change_client2_path_norm, label='Client 2', color='orange')
axes[1, 1].plot(ex4relative_change_client3_path_norm, label='Client 3', color='purple')
axes[1, 1].plot(ex4relative_change_client4_path_norm, label='Client 4', color='brown')
axes[1, 1].plot(ex4sampled_global_index, ex4relative_change_global_path_norm, label='Global', color='red', marker='o')
axes[1, 1].set_title("Relative Change in Path Norm(5Clinets Non-IID Imbalanced FedAdam ResNet)")
axes[1, 1].set_xlabel("Index")
axes[1, 1].set_ylabel("Percentage Change (%)")
axes[1, 1].axhline(0, color='red', linestyle='--', linewidth=1)
axes[1, 1].legend()


#fig.suptitle("5Clients IID Balanced FedAvg ResNet", fontsize=15)
# Adjust spacing
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig("path_norm_percentage_change_Special.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json

def get_json(file_path):
    with open(file_path) as f:
        data = json.load(f)
    return data



def get_experiment_data_5clients(file_path):
    import numpy as np
    import pandas as pd
    training_data0 = get_json(file_path+'/0/training.json')
    training_data1 = get_json(file_path+'/1/training.json')
    training_data2 = get_json(file_path+'/2/training.json')
    training_data3 = get_json(file_path+'/3/training.json')
    training_data4 = get_json(file_path+'/4/training.json')
    validate_data0 = get_json(file_path+'/0/validate.json')
    validate_data1 = get_json(file_path+'/1/validate.json')
    validate_data2 = get_json(file_path+'/2/validate.json')
    validate_data3 = get_json(file_path+'/3/validate.json')
    validate_data4 = get_json(file_path+'/4/validate.json')
    training_data0 = pd.DataFrame(training_data0)
    training_data1 = pd.DataFrame(training_data1)
    training_data2 = pd.DataFrame(training_data2)
    training_data3 = pd.DataFrame(training_data3)
    training_data4 = pd.DataFrame(training_data4)
    validate_data0 = pd.DataFrame(validate_data0)
    validate_data1 = pd.DataFrame(validate_data1)
    validate_data2 = pd.DataFrame(validate_data2)
    validate_data3 = pd.DataFrame(validate_data3)
    validate_data4 = pd.DataFrame(validate_data4)
    return training_data0, training_data1, training_data2, training_data3, training_data4, validate_data0, validate_data1, validate_data2, validate_data3, validate_data4

# %% [markdown]
# | Experiment ID       | Description       |
# |-----------------|----------------|
# | 9070ebff-43ab-4eeb-9a8a-d64024ee8e04| IID Balanced FedAvg ResNet|
# | b458a5f7-193a-46f4-97d5-aac510bb5952| IID Balanced FedAdam ResNet|
# |be13a352-7c46-4fdc-9b1d-779275ab7785|IID Balanced FedAvg FedNet|
# |54a11b13-b2fe-47ef-a0d4-fa2b037f3647|IID Balanced FedAdam FedNet|

# %%
ex1_training_data0, ex1_training_data1, ex1_training_data2, ex1_training_data3, ex1_training_data4, ex1_validate_data0, ex1_validate_data1, ex1_validate_data2, ex1_validate_data3, ex1_validate_data4 = get_experiment_data_5clients('/Users/max/Fedn_Project/CIFAR10_Experiments/5clients/FedNet/be13a352-7c46-4fdc-9b1d-779275ab7785')
ex2_training_data0, ex2_training_data1, ex2_training_data2, ex2_training_data3, ex2_training_data4, ex2_validate_data0, ex2_validate_data1, ex2_validate_data2, ex2_validate_data3, ex2_validate_data4 = get_experiment_data_5clients('/Users/max/Fedn_Project/CIFAR10_Experiments/5clients/FedNet/54a11b13-b2fe-47ef-a0d4-fa2b037f3647')
ex3_training_data0, ex3_training_data1, ex3_training_data2, ex3_training_data3, ex3_training_data4, ex3_validate_data0, ex3_validate_data1, ex3_validate_data2, ex3_validate_data3, ex3_validate_data4 = get_experiment_data_5clients('/Users/max/Fedn_Project/CIFAR10_Experiments/5clients/ResNet/9070ebff-43ab-4eeb-9a8a-d64024ee8e04')
ex4_training_data0, ex4_training_data1, ex4_training_data2, ex4_training_data3, ex4_training_data4, ex4_validate_data0, ex4_validate_data1, ex4_validate_data2, ex4_validate_data3, ex4_validate_data4 = get_experiment_data_5clients('/Users/max/Fedn_Project/CIFAR10_Experiments/5clients/ResNet/b458a5f7-193a-46f4-97d5-aac510bb5952')

# %%
ex1client0_path_norm = ex1_training_data0['path_norm']
ex1client1_path_norm = ex1_training_data1['path_norm']
ex1client2_path_norm = ex1_training_data2['path_norm']
ex1client3_path_norm = ex1_training_data3['path_norm']
ex1client4_path_norm = ex1_training_data4['path_norm']
ex1relative_change_client0_path_norm = ex1client0_path_norm.pct_change() * 100
ex1relative_change_client1_path_norm = ex1client1_path_norm.pct_change() * 100
ex1relative_change_client2_path_norm = ex1client2_path_norm.pct_change() * 100
ex1relative_change_client3_path_norm = ex1client3_path_norm.pct_change() * 100
ex1relative_change_client4_path_norm = ex1client4_path_norm.pct_change() * 100
ex1global_path_norm = ex1_validate_data0['path_norm']
ex1relative_change_global_path_norm = ex1global_path_norm.pct_change() * 100
ex1sampled_global_index = range(0, len(ex1relative_change_client1_path_norm), 5)


ex2client0_path_norm = ex2_training_data0['path_norm']
ex2client1_path_norm = ex2_training_data1['path_norm']
ex2client2_path_norm = ex2_training_data2['path_norm']
ex2client3_path_norm = ex2_training_data3['path_norm']
ex2client4_path_norm = ex2_training_data4['path_norm']
ex2relative_change_client0_path_norm = ex2client0_path_norm.pct_change() * 100
ex2relative_change_client1_path_norm = ex2client1_path_norm.pct_change() * 100
ex2relative_change_client2_path_norm = ex2client2_path_norm.pct_change() * 100
ex2relative_change_client3_path_norm = ex2client3_path_norm.pct_change() * 100
ex2relative_change_client4_path_norm = ex2client4_path_norm.pct_change() * 100
ex2global_path_norm = ex2_validate_data0['path_norm']
ex2relative_change_global_path_norm = ex2global_path_norm.pct_change() * 100
ex2sampled_global_index = range(0, len(ex2relative_change_client1_path_norm), 5)


ex3client0_path_norm = ex3_training_data0['path_norm']
ex3client1_path_norm = ex3_training_data1['path_norm']
ex3client2_path_norm = ex3_training_data2['path_norm']
ex3client3_path_norm = ex3_training_data3['path_norm']
ex3client4_path_norm = ex3_training_data4['path_norm']
ex3relative_change_client0_path_norm = ex3client0_path_norm.pct_change() * 100
ex3relative_change_client1_path_norm = ex3client1_path_norm.pct_change() * 100
ex3relative_change_client2_path_norm = ex3client2_path_norm.pct_change() * 100
ex3relative_change_client3_path_norm = ex3client3_path_norm.pct_change() * 100
ex3relative_change_client4_path_norm = ex3client4_path_norm.pct_change() * 100
ex3global_path_norm = ex3_validate_data0['path_norm'] 
ex3relative_change_global_path_norm = ex3global_path_norm.pct_change() * 100
ex3sampled_global_index = range(0, len(ex3relative_change_client1_path_norm), 3)


ex4client0_path_norm = ex4_training_data0['path_norm']
ex4client1_path_norm = ex4_training_data1['path_norm']
ex4client2_path_norm = ex4_training_data2['path_norm']
ex4client3_path_norm = ex4_training_data3['path_norm']
ex4client4_path_norm = ex4_training_data4['path_norm']
ex4relative_change_client0_path_norm = ex4client0_path_norm.pct_change() * 100
ex4relative_change_client1_path_norm = ex4client1_path_norm.pct_change() * 100
ex4relative_change_client2_path_norm = ex4client2_path_norm.pct_change() * 100
ex4relative_change_client3_path_norm = ex4client3_path_norm.pct_change() * 100
ex4relative_change_client4_path_norm = ex4client4_path_norm.pct_change() * 100
ex4global_path_norm = ex4_validate_data0['path_norm']
ex4relative_change_global_path_norm = ex4global_path_norm.pct_change() * 100
ex4sampled_global_index = range(0, len(ex4relative_change_client1_path_norm), 3)

# %%
import matplotlib.pyplot as plt

# Create a 2x2 layout for subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 10))

axes[0, 0].plot(ex1client0_path_norm, label='Client 0', color='blue')
axes[0, 0].plot(ex1client1_path_norm, label='Client 1', color='green')
axes[0, 0].plot(ex1client2_path_norm, label='Client 2', color='orange')
axes[0, 0].plot(ex1client3_path_norm, label='Client 3', color='purple')
axes[0, 0].plot(ex1client4_path_norm, label='Client 4', color='brown')
axes[0, 0].plot(ex1sampled_global_index, ex1global_path_norm, label='Global', color='red', marker='o')
axes[0, 0].set_title("Local and Global Path Norm(5Clinets IID Balanced FedAvg FedNet)")
axes[0, 0].set_xlabel("Index")
axes[0, 0].set_ylabel("Path Norm")
axes[0, 0].axhline(0, color='red', linestyle='--', linewidth=1)
axes[0, 0].legend()

axes[0, 1].plot(ex2client0_path_norm, label='Client 0', color='blue')
axes[0, 1].plot(ex2client1_path_norm, label='Client 1', color='green')
axes[0, 1].plot(ex2client2_path_norm, label='Client 2', color='orange')
axes[0, 1].plot(ex2client3_path_norm, label='Client 3', color='purple')
axes[0, 1].plot(ex2client4_path_norm, label='Client 4', color='brown')
axes[0, 1].plot(ex2sampled_global_index, ex2global_path_norm, label='Global', color='red', marker='o')
axes[0, 1].set_title("Local and Global Path Norm(5Clinets IID Balanced FedAdam FedNet)")
axes[0, 1].set_xlabel("Index")
axes[0, 1].set_ylabel("Path Norm")
axes[0, 1].axhline(0, color='red', linestyle='--', linewidth=1)
axes[0, 1].legend()


axes[1, 0].plot(ex3client0_path_norm, label='Client 0', color='blue')
axes[1, 0].plot(ex3client1_path_norm, label='Client 1', color='green')
axes[1, 0].plot(ex3client2_path_norm, label='Client 2', color='orange')
axes[1, 0].plot(ex3client3_path_norm, label='Client 3', color='purple')
axes[1, 0].plot(ex3client4_path_norm, label='Client 4', color='brown')
axes[1, 0].plot(ex3sampled_global_index, ex3global_path_norm, label='Global', color='red', marker='o')
axes[1, 0].set_title("Local and Global Path Norm(5Clinets IID Balanced FedAvg ResNet)")
axes[1, 0].set_xlabel("Index")
axes[1, 0].set_ylabel("Path Norm")
axes[1, 0].axhline(0, color='red', linestyle='--', linewidth=1)
axes[1, 0].legend()

axes[1, 1].plot(ex4client0_path_norm, label='Client 0', color='blue')
axes[1, 1].plot(ex4client1_path_norm, label='Client 1', color='green')
axes[1, 1].plot(ex4client2_path_norm, label='Client 2', color='orange')
axes[1, 1].plot(ex4client3_path_norm, label='Client 3', color='purple')
axes[1, 1].plot(ex4client4_path_norm, label='Client 4', color='brown')
axes[1, 1].plot(ex4sampled_global_index, ex4global_path_norm, label='Global', color='red', marker='o')
axes[1, 1].set_title("Local and Global Path Norm(5Clinets IID Balanced FedAdam ResNet)")
axes[1, 1].set_xlabel("Index")
axes[1, 1].set_ylabel("Path Norm")
axes[1, 1].axhline(0, color='red', linestyle='--', linewidth=1)
axes[1, 1].legend()


#fig.suptitle("5Clients IID Balanced FedAvg ResNet", fontsize=15)
# Adjust spacing
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig("path_norm_Special.pdf")
plt.show()
